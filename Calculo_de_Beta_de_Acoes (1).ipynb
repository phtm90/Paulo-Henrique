# %%
import yfinance as yf
import statsmodels.api as sm
from datetime import timedelta
from datetime import datetime

# %%
acoes = ["MGLU3.SA", "^BVSP"]
data = datetime.now()
cinco_anos_atras = data - timedelta(days = 1825)

cotacoes = yf.download(acoes, cinco_anos_atras, data)['Adj Close']

cotacoes
# Out:
# [*********************100%%**********************]  2 of 2 completed
#             MGLU3.SA     ^BVSP
# Date
# 2019-01-07  5.495374   91699.0
# 2019-01-08  5.451089   92032.0
# 2019-01-09  5.432889   93613.0
# 2019-01-10  5.485668   93806.0
# 2019-01-11  5.387087   93658.0
# ...              ...       ...
# 2023-12-26  2.110000  133533.0
# 2023-12-27  2.250000  134194.0
# 2023-12-28  2.160000  134185.0
# 2024-01-02  2.050000  132697.0
# 2024-01-03  2.000000  132834.0
#
# [1240 rows x 2 columns]

# %%
retornos = cotacoes.pct_change().dropna()

retornos
# Out:
#             MGLU3.SA     ^BVSP
# Date
# 2019-01-08 -0.008059  0.003631
# 2019-01-09 -0.003339  0.017179
# 2019-01-10  0.009715  0.002062
# 2019-01-11 -0.017971 -0.001578
# 2019-01-14  0.007883  0.008713
# ...              ...       ...
# 2023-12-26 -0.004717  0.005876
# 2023-12-27  0.066351  0.004950
# 2023-12-28 -0.040000 -0.000067
# 2024-01-02 -0.050926 -0.011089
# 2024-01-03 -0.024390  0.001032
#
# [1239 rows x 2 columns]

# %% [markdown]
# # **Calculo de Beta**

# %%
X = retornos['^BVSP']
Y = retornos[acoes[0]]
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()

# %%
# Beta
print(model.params[1])
print(model.rsquared)
print("---------------------------------------")
print(str(model.summary()))
# Out:
# 1.4152503781703758
# 0.30695749892714486
# ---------------------------------------
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               MGLU3.SA   R-squared:                       0.307
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     547.9
# Date:                Thu, 04 Jan 2024   Prob (F-statistic):          1.32e-100
# Time:                        11:23:32   Log-Likelihood:                 2382.9
# No. Observations:                1239   AIC:                            -4762.
# Df Residuals:                    1237   BIC:                            -4752.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.535      0.593      -0.003       0.001
# ^BVSP          1.4153      0.060     23.407      0.000       1.297       1.534
# ==============================================================================
# Omnibus:                      182.384   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1397.824
# Skew:                           0.432   Prob(JB):                    2.93e-304
# Kurtosis:                       8.131   Cond. No.                         60.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
