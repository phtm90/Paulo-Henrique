# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tickers = "PRIO3.SA MGLU3.SA WEGE3.SA PETR4.SA BBDC3.SA"

carteira = yf.download(tickers, period="5y")["Adj Close"]

ibov = yf.download("^BVSP", period="5y")["Adj Close"]
# Out:
# [*********************100%%**********************]  5 of 5 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
carteira.dropna(inplace=True)
carteira
# Out:
#              BBDC3.SA  MGLU3.SA   PETR4.SA   PRIO3.SA   WEGE3.SA
# Date
# 2019-01-03  17.739466  5.581217   8.780458   2.072471   8.583664
# 2019-01-04  17.350651  5.411353   8.805393   2.089843   8.681684
# 2019-01-07  17.496460  5.495375   8.944314   2.088046   8.546323
# 2019-01-08  17.690866  5.451089   8.890883   2.137966   8.476309
# 2019-01-09  18.060225  5.432889   9.076111   2.163525   8.569663
# ...               ...       ...        ...        ...        ...
# 2023-12-26  15.092750  2.110000  37.330002  45.919998  36.720001
# 2023-12-27  15.202625  2.250000  37.360001  45.939999  36.840000
# 2023-12-28  15.262556  2.160000  37.240002  46.049999  36.910000
# 2024-01-02  15.092750  2.050000  37.779999  45.349998  36.570000
# 2024-01-03  15.100000  2.000000  38.959999  46.880001  36.849998
#
# [1242 rows x 5 columns]

# %%
ibov.dropna(inplace=True)
ibov

# %% [markdown]
# # **Resultados**

# %%
sns.set()
carteira.plot(figsize=(18,8));
